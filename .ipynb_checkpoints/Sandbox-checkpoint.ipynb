# %%
from data_processing import data_load, calculate_emds_and_plot
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from xgboost import XGBClassifier
import matplotlib.pyplot as plt
import shap

# %%
data_dict = data_load()

# %%
# Load your data X, y here
X_train, X_test, y_train, y_test = data_dict["Model"]

model = XGBClassifier(n_estimators=100, max_depth=3, learning_rate=0.1, enable_categorical=True, tree_method='hist', colsample_bytree=0.8)

model.fit(X_train, y_train)
y_pred = model.predict(X_test)
print(f"""Accuracy: {accuracy_score(y_test, y_pred)} 
Precision: {precision_score(y_test,y_pred)} 
Recall: {recall_score(y_test,y_pred)} 
f1 Score: {f1_score(y_test,y_pred)}""")
# Out:
# Accuracy: 0.8152173913043478
# Precision: 0.84
# Recall: 0.8235294117647058
# f1 Score: 0.8316831683168316

# %%
ConfusionMatrixDisplay.from_predictions(y_test, y_pred)
plt.show()

# %%
shap_data = data_dict["Shap"]
explainer = shap.Explainer(model)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(16, 12))
axes = axes.flatten()

for i, (location_name, X) in enumerate(shap_data):
    ax = axes[i]
    
    # Calculate SHAP values for this specific region
    shap_values = explainer(X)
    
    # Tell Matplotlib to make this specific subplot the "active" one
    plt.sca(ax)
    
    # Draw the SHAP plot on the active axis
    shap.plots.bar(shap_values, show=False)
    plt.title(f"{location_name}: Feature Importance", fontsize=14, pad=12)

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 16))
axes = axes.flatten()

for i, (location_name, X) in enumerate(shap_data):
    ax = axes[i]
    
    # Calculate SHAP values for this client
    shap_values = explainer(X)

    plt.sca(ax)
    
    shap.plots.beeswarm(shap_values, show=False, plot_size=None)
    
    # Add the customized title for this specific region
    plt.title(f"{location_name}: Federated Local Interpretation", fontsize=18, pad=15)

# Prevent overlap and ensure x-axis labels are visible on all subplots
plt.tight_layout(pad=3.0) 

plt.show()
# Out:
# C:\Users\aglan\anaconda3\envs\ds_env\Lib\site-packages\numpy\lib\nanfunctions.py:1384: RuntimeWarning: All-NaN slice encountered
#   return _nanquantile_unchecked(

# %%
# At-Risk Patient
cleveland_data = shap_data[0][1]
shap_values = explainer(cleveland_data)

shap.plots.waterfall(shap_values[1])

# %%
# Healthy Patient
cleveland_data = shap_data[0][1]
shap_values = explainer(cleveland_data)

shap.plots.waterfall(shap_values[4])
